# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(np.pi/2)
# Out:
# 1.0

# %%
n=np.arange(8)
print(n)
fs=1600
# Out:
# [0 1 2 3 4 5 6 7]

# %%
x = np.sin(2*np.pi*200*n/fs + 7/8*np.pi) + 2*np.sin(2*np.pi*800*n/fs)
print('x',x)
x2 = np.sin(2*np.pi*200*n/fs + 7/8*np.pi) #+ 2*np.sin(2*np.pi*800*n/fs)
print('x2',x2)
print(x2-x)
# Out:
# x [ 0.38268343 -0.38268343 -0.92387953 -0.92387953 -0.38268343  0.38268343
#   0.92387953  0.92387953]
# x2 [ 0.38268343 -0.38268343 -0.92387953 -0.92387953 -0.38268343  0.38268343
#   0.92387953  0.92387953]
# [ 0.00000000e+00 -2.22044605e-16  4.44089210e-16 -7.77156117e-16
#   9.99200722e-16  2.33146835e-15  1.44328993e-15  5.44009282e-15]

# %%
m=4
N=8
X=np.sum(x*np.exp(-2j * np.pi * n *m/N))
print(np.round(X,2))
# Out:
# (0.13-0j)

# %%
t=np.arange(0,0.01,0.00001)
x_t = np.sin(2*np.pi*200*t + 7/8*np.pi) + 2*np.sin(2*np.pi*800*t)
plt.plot(t,x_t)
